# %% [markdown]
# # In machine learning, an outlier is a data point that stands out a lot from the other data points in a set.

# %% [markdown]
# #Effect of outliers on ML algorithms
# There are certain set of algorithm can impact badly. Those algorithms are Linear regression,Logistic regression, and adaboost.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #How to treat outliers?

# %% [markdown]
# How to treat outliers?
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Trimming:
#
# Trimming basically means removing the outliers but the problem with this approach is that your data gets thin if outliers are more the data will get reduced.
#
# #Capping:
#
# Outliers are sometimes on the lower side or on the higher side. There is no outlier in the middle.What you do is put a limit on the outliers; above a certain value, all are outliers, and below a certain value, all are outliers.

# %% [markdown]
# # How to detect outliers?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The column you are working on.if it is normally distributed.Then it's simple.The speciality of normal distribution is, in between 1 standard deviation there are 68% observations,In between 2 standard deviation there are 95% observations and in between 3 standard deviation there are 99% obsrvations.

# %% [markdown]
# If your particular observation is outside μ ± 3σ in that case you can treat it as outlier.

# %% [markdown]
# # 2. If your data is not normally distributed and the data is skewed

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In this case, you can use the interquartile proximity rule.You plot a boxplot and use the following formula for the minimum value and maximum value:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# min = (Q1–1.5 * IQR)
#
# max = (Q3 + * IQR)
#
# IQR = Q3-Q1
#
# If any number is less than (Q1–1.5*IQR), then it is an outlier, and if any number is bigger than (Q3+1.5-IQR), then it is an outlier.

# %% [markdown]
# # 3. When you have any distribution of the data.You can apply this approach.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# If your observation is greater than the 97.5 percentile, or sometimes the 99 percentile, then it is an outlier.
#
# If your observation is less than the 2.5th percentile, then it is an outlier.

# %% [markdown]
# #Techniques For outlier detection and removal
#
# Z-score treatement
#
# IQR-based filtering
#
# Percentile based
#
# Winsorization
